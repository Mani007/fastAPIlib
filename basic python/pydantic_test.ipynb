# %%
from pydantic import BaseModel
class User(BaseModel):
    id:int
    name:str
    is_active:bool
    
input_data = {"id":'101',"name":"ABC","is_active":True}
user1 = User(**input_data) # We need to provide this ** unpacking dictionary to key value pairs, * only unpack keys
print(user1)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[4], line 8
#       5     is_active:bool
#       7 input_data = {"id":1,"name":"ABC","isActive":True}
# ----> 8 user1 = User(**input_data) # We need to provide this ** unpacking dictionary to key value pairs, * only unpack keys
#       9 print(user1)
#
# File e:\Document backup\pythonfastapi\.venv\Lib\site-packages\pydantic\main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for User
# is_active
#   Field required [type=missing, input_value={'id': 1, 'name': 'ABC', 'isActive': True}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
