# %%
from pydantic import BaseModel
class User(BaseModel):
    id:int
    name:str
    is_active:bool
    
input_data = {"id":'101',"name":"ABC","is_active":True}
user1 = User(**input_data) # We need to provide this ** unpacking dictionary to key value pairs, * only unpack keys
user2 = User(id= input_data['id'],name= input_data['name'],is_active= input_data['is_active']) # We need to provide this ** unpacking dictionary to key value pairs, * only unpack keys
print(user2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       7 input_data = {"id":'101',"name":"ABC","is_active":True}
#       8 user1 = User(**input_data) # We need to provide this ** unpacking dictionary to key value pairs, * only unpack keys
# ----> 9 user2 = User(input_data.values()) # We need to provide this ** unpacking dictionary to key value pairs, * only unpack keys
#      10 print(user2)
#
# TypeError: BaseModel.__init__() takes 1 positional argument but 2 were given

# %%
from pydantic import BaseModel
from typing import List, Dict, Optional
class Cart(BaseModel):
    user_id:int
