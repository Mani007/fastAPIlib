# %%
class Base:
    # id =0
    # name = "abc"
    def __init__(self, id1,name):
        self.__id1 = id1
        self.__name = name
    def printdata(self):
        print("The id is " + str(self.__id1) +" and name is " + str(self.__name))

# %%
b1=Base(10,'abc')
b1.printdata()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 b1=Base(10,'abc')
# ----> 2 b1.printdata()
#
# Cell In[4], line 8, in Base.printdata(self)
#       7 def printdata(self):
# ----> 8     print("The id is " + str(self.id) +" and name is " + str(self.name))
#
# AttributeError: 'Base' object has no attribute 'id'

# %%
print(b1.__dict__)
# Out:
# {'id': 10, 'name': 'abc'}
