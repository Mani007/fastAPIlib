# %%
class Base:
    # id =0
    # name = "abc"
    def __init__(self, id1,name):
        self.__id1 = id1
        self.__name = name
    def changeattr(self,id1,name):
        self.__id1 = id1
        self.__name = name
    def printdata(self):
        print("The id is " + str(self.__id1) +" and name is " + str(self.__name))

# %%
b1=Base(10,'abc')
b1.printdata()
# Out:
# The id is 10 and name is abc

# %%
print(b1.__dict__)
# Out:
# {'_Base__id1': 10, '_Base__name': 'abc'}

# %%
b1.changeattr(25,"c++")

# %%
print(b1.__dict__)
# Out:
# {'_Base__id1': 25, '_Base__name': 'c++'}
